# %% [markdown]
# <a href="https://colab.research.google.com/github/preet7890/Codealpha_hangmangam/blob/main/Internship_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project**
# ---
# ## **QueryMart - Retail Sales Database**

# %%
# Step 1: Import Required Libraries
import sqlite3
import requests
import pandas as pd

# %%
import requests
url = "https://github.com/YBIFoundation/SQL/raw/main/QueryMart.db"
response = requests.get(url)
with open("QueryMart.db", "wb") as f:
    f.write(response.content)
conn = sqlite3.connect("QueryMart.db")
print("Database downloaded successfully")
# Out:
# Database downloaded successfully

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Create helper function
def sql(query):
    return pd.read_sql(query, conn)

# %%
sql(" SELECT name FROM sqlite_master WHERE type='table';")
# Out:
#           name
# 0    customers
# 1     products
# 2   warehouses
# 3       orders
# 4  order_items

# %%
# Customer Table
sql("SELECT * FROM customers;")
# Out:
#     customer_id  customer_name       city  age  gender customer_segment
# 0      CUST0001   Arjun Sharma  Hyderabad   33    Male          Regular
# 1      CUST0002  Arjun Agarwal  Ahmedabad   23  Female          Regular
# 2      CUST0003    Aarav Verma    Chennai   32    Male              VIP
# 3      CUST0004    Amit Chopra  Ahmedabad   44    Male          Premium
# 4      CUST0005    Nisha Patel      Delhi   28  Female          Premium
# ..          ...            ...        ...  ...     ...              ...
# 995    CUST0996    Amit Sharma    Kolkata   40    Male          Premium
# 996    CUST0997   Vivaan Mehta     Jaipur   53  Female              VIP
# 997    CUST0998   Simran Singh    Lucknow   29  Female          Premium
# 998    CUST0999     Riya Patel    Lucknow   53    Male          Regular
# 999    CUST1000    Kavya Gupta     Jaipur   36  Female              VIP
#
# [1000 rows x 6 columns]

# %%
# Product Table
sql("SELECT * FROM products")
# Out:
#    product_id       product_name     category  unit_price
# 0     PROD001             Laptop  Electronics    18789.55
# 1     PROD002         Smartphone  Electronics    47540.64
# 2     PROD003             Tablet  Electronics    36626.50
# 3     PROD004        Smart Watch  Electronics    29973.06
# 4     PROD005  Bluetooth Speaker  Electronics     7885.33
# 5     PROD006         Headphones  Electronics     7884.13
# 6     PROD007           Keyboard  Electronics     2998.37
# 7     PROD008              Mouse  Electronics    43322.19
# 8     PROD009            Monitor  Electronics    30095.64
# 9     PROD010         Power Bank  Electronics    35432.82
# 10    PROD011      Mixer Grinder         Home     1127.17
# 11    PROD012    Electric Kettle         Home    48498.50
# 12    PROD013     Vacuum Cleaner         Home    41638.89
# 13    PROD014       Air Purifier         Home    10695.72
# 14    PROD015               Iron         Home     9173.07
# ...

# %%
# Orders Table
sql("SELECT * FROM order_items")
# Out:
#           item_id  order_id product_id  quantity  unit_price  \
# 0      ITEM000001  ORD00001    PROD022         4     7060.74
# 1      ITEM000002  ORD00002    PROD003         1    36626.50
# 2      ITEM000003  ORD00002    PROD048         2    26051.39
# 3      ITEM000004  ORD00002    PROD045         5    13013.12
# 4      ITEM000005  ORD00003    PROD036         2    40439.03
# ...           ...       ...        ...       ...         ...
# 15126  ITEM015127  ORD05000    PROD032         4     8609.15
# 15127  ITEM015128  ORD05000    PROD008         5    43322.19
# 15128  ITEM015129  ORD05000    PROD048         4    26051.39
# 15129  ITEM015130  ORD05000    PROD024         3    18381.46
# 15130  ITEM015131  ORD05000    PROD029         5    29661.49
#
#        discount_percent  gross_amount  discount_amount  net_amount  \
# 0                    20      28242.96          5648.59    22594.37
# 1                     0      36626.50             0.00    36626.50
# ...

# %%
# Calculate Total Revenue
sql("SELECT SUM(net_amount) FROM order_items")
# Out:
#    SUM(net_amount)
# 0     8.979608e+08

# %%
sql("SELECT * FROM orders")
# Out:
#       order_id customer_id warehouse_id  order_date payment_method  \
# 0     ORD00001    CUST0465        WH001  2025-07-07    Net Banking
# 1     ORD00002    CUST0905        WH001  2025-04-05    Net Banking
# 2     ORD00003    CUST0245        WH006  2025-11-14            UPI
# 3     ORD00004    CUST0839        WH007  2025-10-03    Credit Card
# 4     ORD00005    CUST0785        WH009  2025-09-12    Credit Card
# ...        ...         ...          ...         ...            ...
# 4995  ORD04996    CUST0389        WH006  2025-12-12    Credit Card
# 4996  ORD04997    CUST0206        WH003  2025-11-16    Credit Card
# 4997  ORD04998    CUST0078        WH005  2025-10-24    Credit Card
# 4998  ORD04999    CUST0014        WH008  2025-12-27            UPI
# 4999  ORD05000    CUST0490        WH004  2025-05-26           Cash
#
#      order_status
# 0       Delivered
# 1         Shipped
# 2       Delivered
# 3       Delivered
# 4       Delivered
# ...           ...
# 4995      Shipped
# ...

# %%
# Find unique payment methods
sql("SELECT DISTINCT payment_method	FROM orders")
# Out:
#   payment_method
# 0    Net Banking
# 1            UPI
# 2    Credit Card
# 3           Cash
# 4     Debit Card

# %%
# Find unique order statuses
sql("SELECT DISTINCT order_status FROM orders")
# Out:
#   order_status
# 0    Delivered
# 1      Shipped
# 2    Cancelled
# 3     Returned

# %%
#Find all delivered orders
sql("SELECT * FROM orders WHERE order_status = 'Delivered'")
# Out:
#       order_id customer_id warehouse_id  order_date payment_method  \
# 0     ORD00001    CUST0465        WH001  2025-07-07    Net Banking
# 1     ORD00003    CUST0245        WH006  2025-11-14            UPI
# 2     ORD00004    CUST0839        WH007  2025-10-03    Credit Card
# 3     ORD00005    CUST0785        WH009  2025-09-12    Credit Card
# 4     ORD00006    CUST0420        WH006  2025-06-15            UPI
# ...        ...         ...          ...         ...            ...
# 3706  ORD04990    CUST0647        WH008  2025-10-26            UPI
# 3707  ORD04992    CUST0789        WH008  2025-07-26           Cash
# 3708  ORD04994    CUST0295        WH005  2025-04-10            UPI
# 3709  ORD04999    CUST0014        WH008  2025-12-27            UPI
# 3710  ORD05000    CUST0490        WH004  2025-05-26           Cash
#
#      order_status
# 0       Delivered
# 1       Delivered
# 2       Delivered
# 3       Delivered
# 4       Delivered
# ...           ...
# 3706    Delivered
# ...

# %%
# Find all orders placed after June 2025
sql("SELECT * FROM orders WHERE order_date >= '2025-07-01'")
# Out:
#       order_id customer_id warehouse_id  order_date payment_method  \
# 0     ORD00001    CUST0465        WH001  2025-07-07    Net Banking
# 1     ORD00003    CUST0245        WH006  2025-11-14            UPI
# 2     ORD00004    CUST0839        WH007  2025-10-03    Credit Card
# 3     ORD00005    CUST0785        WH009  2025-09-12    Credit Card
# 4     ORD00007    CUST0069        WH001  2025-12-04    Credit Card
# ...        ...         ...          ...         ...            ...
# 2524  ORD04995    CUST0156        WH003  2025-07-07     Debit Card
# 2525  ORD04996    CUST0389        WH006  2025-12-12    Credit Card
# 2526  ORD04997    CUST0206        WH003  2025-11-16    Credit Card
# 2527  ORD04998    CUST0078        WH005  2025-10-24    Credit Card
# 2528  ORD04999    CUST0014        WH008  2025-12-27            UPI
#
#      order_status
# 0       Delivered
# 1       Delivered
# 2       Delivered
# 3       Delivered
# 4       Delivered
# ...           ...
# 2524    Cancelled
# ...

# %%
# Find orders placed between January and March 2025
sql("SELECT * FROM orders WHERE order_date BETWEEN 	'2025-01-01' AND 	'2025-03-31'")
# Out:
#       order_id customer_id warehouse_id  order_date payment_method  \
# 0     ORD00008    CUST0207        WH002  2025-01-17           Cash
# 1     ORD00009    CUST0585        WH007  2025-01-17           Cash
# 2     ORD00016    CUST0968        WH004  2025-02-09    Net Banking
# 3     ORD00022    CUST0547        WH010  2025-03-22           Cash
# 4     ORD00027    CUST0744        WH001  2025-01-01     Debit Card
# ...        ...         ...          ...         ...            ...
# 1234  ORD04980    CUST0655        WH008  2025-01-05    Credit Card
# 1235  ORD04981    CUST0973        WH008  2025-03-27           Cash
# 1236  ORD04982    CUST0124        WH009  2025-03-01     Debit Card
# 1237  ORD04983    CUST0710        WH008  2025-03-07    Net Banking
# 1238  ORD04985    CUST0150        WH002  2025-02-12            UPI
#
#      order_status
# 0       Delivered
# 1       Delivered
# 2       Delivered
# 3       Cancelled
# 4       Delivered
# ...           ...
# 1234    Delivered
# ...

# %%
# Find the 10 most expensive products
sql("SELECT * FROM products ORDER BY unit_price DESC LIMIT 10")
# Out:
#   product_id     product_name     category  unit_price
# 0    PROD012  Electric Kettle         Home    48498.50
# 1    PROD035         Lipstick       Beauty    48285.04
# 2    PROD002       Smartphone  Electronics    47540.64
# 3    PROD034       Face Cream       Beauty    47449.39
# 4    PROD044            Sugar      Grocery    45475.09
# 5    PROD008            Mouse  Electronics    43322.19
# 6    PROD013   Vacuum Cleaner         Home    41638.89
# 7    PROD036          Perfume       Beauty    40439.03
# 8    PROD026            Dress      Fashion    39280.28
# 9    PROD003           Tablet  Electronics    36626.50

# %%
# Calculate average order-item revenue
sql("SELECT AVG(net_amount) FROM order_items")
# Out:
#    AVG(net_amount)
# 0     59345.768945

# %%
# Find number of products in each category
sql("SELECT category, COUNT(*), AVG(unit_price) FROM products GROUP BY category")
# Out:
#       category  COUNT(*)  AVG(unit_price)
# 0       Beauty        10        25512.608
# 1  Electronics        10        26054.823
# 2      Fashion        10        20079.324
# 3      Grocery        10        20287.395
# 4         Home        10        19823.867
